# %%
from fronteira_decisao_simulada import visualizar_classificacao

# %%
N = 4000 # pontos totais
n = 130  # pontos alvo

precisao = 0.4
recall = 0.8

distribuicao = 'normal' # se essa string for diferente de normal, a distribuicao eh uniforme

skewness = 'media' # alta, baixa ou media - o default eh media

visualizar_classificacao(n, N, precisao, recall,
    ruido = '', distribuicao = distribuicao, skewness = skewness, printar_info = True,
                        expoentes = 'automatico')
# Out:
# expoentes (0.2, 0.29159350353130375)

# %%
N = 4000 # pontos totais
n = 130  # pontos alvo

precisao = 0.4
recall = 0.8

distribuicao = 'uniforme' # se essa string for diferente de normal, a distribuicao eh uniforme

skewness = 'media' # alta, baixa ou media - o default eh media

visualizar_classificacao(n, N, precisao, recall,
    ruido = '', distribuicao = distribuicao, skewness = skewness, printar_info = True,
                        expoentes = 'automatico')
# Out:
# expoentes (0.44946301984388315, 1.221616702568034)
